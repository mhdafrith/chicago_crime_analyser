# %%
import pandas as pd
filepath='/content/drive/MyDrive/Copy of Crime_Data.xlsx'
df=pd.read_excel(filepath)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 549999 entries, 0 to 549998
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    549999 non-null  int64
#  1   Case Number           549999 non-null  object
#  2   Date                  549999 non-null  datetime64[ns]
#  3   Block                 549999 non-null  object
#  4   IUCR                  549999 non-null  object
#  5   Primary Type          549999 non-null  object
#  6   Description           549999 non-null  object
#  7   Location Description  548326 non-null  object
#  8   Arrest                549999 non-null  bool
#  9   Domestic              549999 non-null  bool
#  10  Beat                  549999 non-null  int64
#  11  District              549999 non-null  int64
#  12  Ward                  213674 non-null  float64
#  13  Community Area        215093 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                           0
# Case Number                  0
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      1673
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                     0
# Ward                    336325
# Community Area          334906
# FBI Code                     0
# X Coordinate              6912
# Y Coordinate              6912
# Year                         0
# Updated On                   0
# Latitude                  6912
# Longitude                 6912
# Location                  6912
# dtype: int64

# %%
df['ID'].nunique()
# Out:
# 549999

# %%
df['Case Number'].nunique()
# Out:
# 549434

# %%
case_counts = df['Case Number'].value_counts()
case_counts
# Out:
# Case Number
# HZ140230    6
# HJ590004    6
# JC470284    5
# HP296582    5
# HS256531    5
#            ..
# JH263344    1
# JH262973    1
# JH271357    1
# JH263185    1
# G627247     1
# Name: count, Length: 549434, dtype: int64

# %%
df=df.drop_duplicates(subset='Case Number', keep='first')

# %%
df['Location Description'].value_counts()
# Out:
# Location Description
# STREET                 165841
# RESIDENCE               90195
# APARTMENT               58686
# SIDEWALK                30151
# OTHER                   14865
#                         ...
# BEACH                       1
# CLEANERS/LAUNDROMAT         1
# LAGOON                      1
# POOLROOM                    1
# LOADING DOCK                1
# Name: count, Length: 210, dtype: int64

# %%
df[df['Location Description'].isnull()]
# Out:
#               ID Case Number                Date                  Block  IUCR  \
# 421     13207457    JG419448 2023-09-06 14:20:00     032XX N OCONTO AVE  1153
# 894     13209655    JG422078 2023-05-30 09:30:00  003XX W WASHINGTON ST  1242
# 1147    13203348    JG415071 2023-09-07 14:35:00    052XX S NATCHEZ AVE  1153
# 1522    13209657    JG422289 2023-02-02 08:15:00      018XX N HONORE ST  1153
# 1696    13206379    JG418537 2007-01-01 16:40:00       053XX S SHORE DR  1153
# ...          ...         ...                 ...                    ...   ...
# 198066  13175904    JG382451 2021-04-05 12:10:00   008XX N PARKSIDE AVE  1153
# 198079  13183724    JG391153 2021-04-06 12:00:00    001XX W DIVISION ST  1153
# 198084  13177012    JG383875 2021-11-22 00:00:00    061XX W WARWICK AVE  1153
# 205871   1438434     G162638 2001-03-22 00:30:00  034XX N MARSHFIELD AV  1200
# 238474   1431283     G155531 2001-03-18 21:37:10       028XX S KOLIN AV   460
#
# ...

# %%
df['Location Description'].fillna('OTHER', inplace=True)

df
# Out:
# <ipython-input-11-ca6f14a5e4af>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Location Description'].fillna('OTHER', inplace=True)
#               ID Case Number                Date                      Block  \
# 0        5741943    HN549294 2007-08-25 09:22:18         074XX N ROGERS AVE
# 1          25953    JE240540 2021-05-24 15:06:00        020XX N LARAMIE AVE
# 2          26038    JE279849 2021-06-26 09:24:00      062XX N MC CORMICK RD
# ...

# %%
df['Location Description'] = df['Location Description'].replace('OTHER (SPECIFY)', 'OTHER')

# %%
df=df.sort_values(by=['District', 'Ward', 'Community Area'], ascending=[True, True, True])
df['District'].fillna(method='ffill', inplace=True)
df['Ward'].fillna(method='ffill', inplace=True)
df['Community Area'].fillna(method='ffill', inplace=True)
df
# Out:
# <ipython-input-13-5f3e173842c5>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['District'].fillna(method='ffill', inplace=True)
# <ipython-input-13-5f3e173842c5>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['District'].fillna(method='ffill', inplace=True)
# ...

# %%
df.isnull().sum()
# Out:
# ID                         0
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description       0
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                       0
# Community Area             0
# FBI Code                   0
# X Coordinate            6912
# Y Coordinate            6912
# Year                       0
# Updated On                 0
# Latitude                6912
# Longitude               6912
# Location                6912
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 549434 entries, 7965 to 200092
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    549434 non-null  int64
#  1   Case Number           549434 non-null  object
#  2   Date                  549434 non-null  datetime64[ns]
#  3   Block                 549434 non-null  object
#  4   IUCR                  549434 non-null  object
#  5   Primary Type          549434 non-null  object
#  6   Description           549434 non-null  object
#  7   Location Description  549434 non-null  object
#  8   Arrest                549434 non-null  bool
#  9   Domestic              549434 non-null  bool
#  10  Beat                  549434 non-null  int64
#  11  District              549434 non-null  int64
#  12  Ward                  549434 non-null  float64
#  13  Community Area        549434 non-null  float64
# ...

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 542522 entries, 199980 to 200092
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    542522 non-null  int64
#  1   Case Number           542522 non-null  object
#  2   Date                  542522 non-null  datetime64[ns]
#  3   Block                 542522 non-null  object
#  4   IUCR                  542522 non-null  object
#  5   Primary Type          542522 non-null  object
#  6   Description           542522 non-null  object
#  7   Location Description  542522 non-null  object
#  8   Arrest                542522 non-null  bool
#  9   Domestic              542522 non-null  bool
#  10  Beat                  542522 non-null  int64
#  11  District              542522 non-null  int64
#  12  Ward                  542522 non-null  float64
#  13  Community Area        542522 non-null  float64
# ...

# %%
from google.colab import files

# Save DataFrame to a CSV file
df.to_csv('cleaned_chicago_crime_data.csv', index=False)

# Download the CSV file
files.download('cleaned_chicago_crime_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2df8cfd7806b> in <cell line: 4>()
#       2
#       3 # Save DataFrame to a CSV file
# ----> 4 df.to_csv('cleaned_chicago_crime_data.csv', index=False)
#       5
#       6 # Download the CSV file
#
# NameError: name 'df' is not defined

# %%
# Convert multiple columns from float to int
df[['Ward', 'Community Area']] = df[['Ward', 'Community Area']].astype('int')

print(df.dtypes)
# Out:
# ID                               int64
# Case Number                     object
# Date                    datetime64[ns]
# Block                           object
# IUCR                            object
# Primary Type                    object
# Description                     object
# Location Description            object
# Arrest                            bool
# Domestic                          bool
# Beat                             int64
# District                         int64
# Ward                             int64
# Community Area                   int64
# FBI Code                        object
# X Coordinate                   float64
# Y Coordinate                   float64
# Year                             int64
# Updated On              datetime64[ns]
# Latitude                       float64
# Longitude                      float64
# Location                        object
# dtype: object
# <ipython-input-18-25d241f3a33c>:2: SettingWithCopyWarning:
# ...

# %%
# Grouping the data by 'Primary Type' and counting the occurrences
bar_chart = df.groupby('Primary Type').size().sort_values(ascending=False).reset_index()

# Renaming columns for better readability
bar_chart.columns = ['Primary Type', 'Count']

# Displaying the top rows
bar_chart.head()
# Out:
#       Primary Type   Count
# 0            THEFT  111499
# 1          BATTERY  100475
# 2  CRIMINAL DAMAGE   59907
# 3          ASSAULT   39865
# 4        NARCOTICS   39147

# %%
import matplotlib.pyplot as plt

# Slicing the top 10 categories
top_10 = bar_chart.head(10)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(top_10['Primary Type'], top_10['Count'], color='skyblue')

# Adding data labels on top of the bars
for bar in bars:
    plt.text(
        bar.get_x() + bar.get_width() / 2,  # X-coordinate (center of the bar)
        bar.get_height() + 5,              # Y-coordinate (slightly above the bar)
        str(int(bar.get_height())),        # Label (height of the bar)
        ha='center',                       # Horizontal alignment
        va='bottom',                       # Vertical alignment
        fontsize=10,                       # Font size
        color='black'                      # Text color
    )

# Formatting the chart
plt.xticks(rotation=90)
plt.title('Top 10 Crime Counts by Crime Type')
plt.xlabel('Primary Type')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
pie_chart=df.Domestic.value_counts().sort_values(ascending=False).reset_index()
pie_chart.columns=['Domestic','Count']
pie_chart
# Out:
#    Domestic   Count
# 0     False  451752
# 1      True   90770

# %%
import matplotlib.pyplot as plt
labels = ['Non-Domestic','Domestic']
pie_chart = pie_chart['Count']
colors = ['red','green']
plt.pie(pie_chart, labels = labels, colors = colors, autopct = '%1.2f%%')
plt.show()
